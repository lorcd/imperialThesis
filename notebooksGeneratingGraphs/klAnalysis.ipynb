# %% [markdown]
# Here we will analyze the effect of the number of samples we take from the posterior and prior distributions in the KL divergence approximation function.

# %%
import csv
import matplotlib as plt
import numpy as np
import seaborn as sns
import pandas as pd
import scipy.stats

from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
#First let's graph 
klAccs = pd.read_csv('/drive/MyDrive/Colab Notebooks/Thesis Notebooks/results/klAccuracies.csv')
klAccs = klAccs.rename(columns={"testAcc":"Test Accuracy", "trainAcc":"Train Accuracy"})

# %%
klAccs_melted = klAccs.melt("klSampleNumber",var_name="Test Accuracy&Train Accuracy",value_name="accuracy").rename(columns={"Test Accuracy&Train Accuracy":"Test&Train"})
sns.relplot(data=klAccs_melted, x="klSampleNumber", y="accuracy", hue="Test&Train",kind="line",);
